# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("q2_data_label.csv")

# %%
features_to_plot = ['x', 'y', 'c']

# %%
df_to_plot = data.ix[::,features_to_plot]

# %%
df_to_plot
# Out:
#             x      y    c
# 0    -0.88100 -6.240  0.0
# 1     1.54000  4.190  0.0
# 2    -1.13000  4.920  0.0
# 3    -0.57800 -1.930  1.0
# 4    -2.82000 -4.980  0.0
# 5     3.86000  1.420  0.0
# 6     1.17000 -0.360  1.0
# 7    -2.92000 -1.490  0.0
# 8     0.37000 -2.610  0.0
# 9    -0.59100 -4.200  0.0
# 10   -3.11000 -0.192  0.0
# 11   -0.13100  2.960  0.0
# 12   -0.59800 -4.760  0.0
# 13    1.38000  4.090  0.0
# 14   -0.61000 -0.370  1.0
# 15   -1.27000 -0.959  1.0
# 16    0.57100  4.180  0.0
# 17   -3.17000 -0.624  0.0
# 18   -1.26000 -4.010  0.0
# 19   -1.86000  0.920  0.0
# 20    2.32000  3.960  0.0
# 21    0.26000  2.740  0.0
# 22    1.30000  1.220  1.0
# 23   -2.43000 -1.420  0.0
# 24   -0.82400  4.490  0.0
# 25   -0.13000 -3.950  0.0
# 26    1.20000 -3.700  0.0
# 27    0.50400  3.270  0.0
# 28   -0.82700  2.770  0.0
# 29    2.49000 -1.210  0.0
# ...       ...    ...  ...
# 4970  0.50500 -1.730  1.0
# 4971  0.04030  0.324  1.0
# 4972 -0.71500 -1.690  1.0
# 4973  3.93000  3.220  0.0
# 4974  1.58000  4.260  0.0
# 4975 -1.87000 -4.360  0.0
# 4976  0.30100 -9.560  0.0
# 4977 -0.00736  2.750  0.0
# 4978 -0.90800 -1.320  1.0
# 4979  1.53000  6.550  0.0
# 4980  1.81000  0.321  0.0
# 4981 -2.43000 -2.450  0.0
# 4982 -3.18000 -0.170  0.0
# 4983  2.03000 -2.390  0.0
# 4984  2.10000  0.235  0.0
# 4985  2.99000  2.260  0.0
# 4986 -0.92600 -0.106  1.0
# 4987 -4.90000 -6.590  0.0
# 4988  0.48300 -1.080  1.0
# 4989  0.87500  3.380  0.0
# 4990  1.31000  2.530  0.0
# 4991 -2.77000 -1.290  0.0
# 4992 -1.76000 -1.500  0.0
# 4993  0.32300 -0.756  1.0
# 4994  3.78000 -0.907  0.0
# 4995 -4.18000 -3.110  0.0
# 4996  1.20000  1.790  1.0
# 4997  0.07010 -1.790  1.0
# 4998 -1.46000 -1.050  1.0
# 4999 -0.53900  1.030  1.0
#
# [5000 rows x 3 columns]

# %%
# %matplotlib inline

# %%
sns.pairplot(df_to_plot, hue="c")

# %%
dataset = np.loadtxt("q2_data.csv", delimiter=",")

# %%
dataset
# Out:
# array([[-0.88130967, -6.24187192,  0.        ],
#        [ 1.54029478,  4.18513032,  0.        ],
#        [-1.13016968,  4.92378479,  0.        ],
#        ...,
#        [ 0.07013473, -1.79114042,  1.        ],
#        [-1.46368246, -1.05353431,  1.        ],
#        [-0.53926228,  1.03086848,  1.        ]])

# %%
# %matplotlib inline

# %%
plt.scatter(dataset[:,0],dataset[:,1], c=['blue', 'green'], s=10)
